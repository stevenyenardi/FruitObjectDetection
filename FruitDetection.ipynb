# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !scp '/content/drive/My Drive/SUTD CV - Steven Yenardi/Dataset Fruits.zip' '/content/Dataset Fruits.zip'
# !unzip '/content/Dataset Fruits.zip' -d '/content/'
# Out:
# Archive:  /content/Dataset Fruits.zip
#    creating: /content/Fruit Images/
#   inflating: /content/Fruit Images/data.yaml
#    creating: /content/Fruit Images/train/
#    creating: /content/Fruit Images/train/images/
#   inflating: /content/Fruit Images/train/images/71Banana02034_png.rf.b973bcc82559c134dee67c47bb41b9e6.jpg
#   inflating: /content/Fruit Images/train/images/79Banana02063_png.rf.f533bea5d7eb9f7241d131845f3bfff1.jpg
#   inflating: /content/Fruit Images/train/images/87Banana02109_png.rf.d5f1577b31c9c0bd24f8f3d9b5853405.jpg
#   inflating: /content/Fruit Images/train/images/Aimages.jpeg
#   inflating: /content/Fruit Images/train/images/Aimg_01.jpeg
#   inflating: /content/Fruit Images/train/images/Aimg_1001.jpeg
#   inflating: /content/Fruit Images/train/images/Aimg_101.jpeg
#   inflating: /content/Fruit Images/train/images/Aimg_1071.jpeg
#   inflating: /content/Fruit Images/train/images/Aimg_1091.jpeg
#   inflating: /content/Fruit Images/train/images/Aimg_1101.jpeg
# ...

# %%
# %pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.9/906.9 kB 23.6 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

path = '/content/Fruit Images/data.yaml'
model = YOLO("yolo11n.pt")
training = model.train(data = path, epochs = 30, imgsz=640, device = 0, batch = 16, lr0 = 0.001, optimizer = 'adam',weight_decay = 0.0005, augment = True, pretrained = True)
# Out:
# Ultralytics 8.3.61 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from google.colab import files

# !zip -r /content/runs.zip /content/runs
files.download("/content/runs.zip")
# Out:
#   adding: content/runs/ (stored 0%)
#   adding: content/runs/detect/ (stored 0%)
#   adding: content/runs/detect/train2/ (stored 0%)
#   adding: content/runs/detect/train2/confusion_matrix.png (deflated 29%)
#   adding: content/runs/detect/train2/P_curve.png (deflated 10%)
#   adding: content/runs/detect/train2/val_batch0_pred.jpg (deflated 9%)
#   adding: content/runs/detect/train2/val_batch2_labels.jpg (deflated 9%)
#   adding: content/runs/detect/train2/labels.jpg (deflated 28%)
#   adding: content/runs/detect/train2/args.yaml (deflated 52%)
#   adding: content/runs/detect/train2/F1_curve.png (deflated 10%)
#   adding: content/runs/detect/train2/weights/ (stored 0%)
#   adding: content/runs/detect/train2/weights/best.pt (deflated 10%)
#   adding: content/runs/detect/train2/weights/last.pt (deflated 10%)
#   adding: content/runs/detect/train2/train_batch2.jpg (deflated 6%)
#   adding: content/runs/detect/train2/events.out.tfevents.1736864532.56c6c9ba8000.267.1 (deflated 92%)
# ...
